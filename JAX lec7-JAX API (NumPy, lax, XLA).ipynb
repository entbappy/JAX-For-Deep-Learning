# %% [markdown]
# # JAX API structure
#
# <img src="https://chefsmandala.com/wp-content/uploads/2018/03/Onion-Red.jpg" width="640">

# %% [markdown]
# - NumPy <-> lax <-> XLA
# - lax API is stricter and more powerful
# - It's a Python wrapper around XLA

# %%
import jax.numpy as jnp
import numpy as np
from jax import jit, grad, vmap
from jax import random
import matplotlib.pyplot as plt

# JAX's low level API 
# (lax is just an anagram for XLA, not completely sure how they came up with name JAX)
from jax import lax

# %%
# Example 1: lax is stricter

print(jnp.add(1, 1.0))  # jax.numpy API implicitly promotes mixed types
print(lax.add(1, 1.0))  # jax.lax API requires explicit type promotion
# Out:
# 2.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-dab0a0a399fe> in <module>()
#       2
#       3 print(jnp.add(1, 1.0))  # jax.numpy API implicitly promotes mixed types
# ----> 4 print(lax.add(1, 1.0))  # jax.lax API requires explicit type promotion
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in add(x, y)
#     364 def add(x: Array, y: Array) -> Array:
#     365   r"""Elementwise addition: :math:`x + y`."""
# --> 366   return add_p.bind(x, y)
#     367
#     368 def sub(x: Array, y: Array) -> Array:
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in bind(self, *args, **params)
#     270         args, used_axis_names(self, params) if self._dispatch_on_params else None)
#     271     tracers = map(top_trace.full_raise, args)
# --> 272     out = top_trace.process_primitive(self, tracers, params)
#     273     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     274
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in process_primitive(self, primitive, tracers, params)
#     622
#     623   def process_primitive(self, primitive, tracers, params):
# --> 624     return primitive.impl(*tracers, **params)
#     625
#     626   def process_call(self, primitive, f, tracers, params):
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in apply_primitive(prim, *args, **params)
#     415   """Impl rule that compiles and runs a single primitive 'prim' using XLA."""
#     416   compiled_fun = xla_primitive_callable(prim, *unsafe_map(arg_spec, args),
# --> 417                                         **params)
#     418   return compiled_fun(*args)
#     419
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/util.py in wrapper(*args, **kwargs)
#     185         return f(*args, **kwargs)
#     186       else:
# --> 187         return cached(config._trace_context(), *args, **kwargs)
#     188
#     189     wrapper.cache_clear = cached.cache_clear
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/util.py in cached(_, *args, **kwargs)
#     178     @functools.lru_cache(max_size)
#     179     def cached(_, *args, **kwargs):
# --> 180       return f(*args, **kwargs)
#     181
#     182     @functools.wraps(f)
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in xla_primitive_callable(prim, *arg_specs, **params)
#     438       return out,
#     439   compiled = _xla_callable_uncached(lu.wrap_init(prim_fun), device, None,
# --> 440                                     prim.name, donated_invars, *arg_specs)
#     441   if not prim.multiple_results:
#     442     return lambda *args, **kw: compiled(*args, **kw)[0]
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in _xla_callable_uncached(fun, device, backend, name, donated_invars, *arg_specs)
#     758                            donated_invars, *arg_specs):
#     759   return lower_xla_callable(fun, device, backend, name, donated_invars,
# --> 760                             *arg_specs).compile().unsafe_call
#     761
#     762 _xla_callable = lu.cache(_xla_callable_uncached)
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in lower_xla_callable(fun, device, backend, name, donated_invars, *arg_specs)
#     770   abstract_args, arg_devices = unzip2(arg_specs)
#     771   jaxpr, out_avals, consts = pe.trace_to_jaxpr_final(
# --> 772       fun, abstract_args, pe.debug_info_final(fun, "jit"))
#     773   if any(isinstance(c, core.Tracer) for c in consts):
#     774     raise UnexpectedTracerError("Encountered an unexpected tracer.")
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr_final(fun, in_avals, debug_info)
#    1540     main.jaxpr_stack = ()  # type: ignore
#    1541     with core.new_sublevel():
# -> 1542       jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1543     del fun, main
#    1544   return jaxpr, out_avals, consts
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1518     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1519     in_tracers = map(trace.new_arg, in_avals)
# -> 1520     ans = fun.call_wrapped(*in_tracers)
#    1521     out_tracers = map(trace.full_raise, ans)
#    1522     jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# /usr/local/lib/python3.7/dist-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in prim_fun(*args)
#     432   device = _device_from_arg_devices(arg_devices)
#     433   def prim_fun(*args):
# --> 434     out = prim.bind(*args, **params)
#     435     if prim.multiple_results:
#     436       return out
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in bind(self, *args, **params)
#     270         args, used_axis_names(self, params) if self._dispatch_on_params else None)
#     271     tracers = map(top_trace.full_raise, args)
# --> 272     out = top_trace.process_primitive(self, tracers, params)
#     273     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     274
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/partial_eval.py in process_primitive(self, primitive, tracers, params)
#    1315   def process_primitive(self, primitive, tracers, params):
#    1316     avals = [t.aval for t in tracers]
# -> 1317     out_avals = primitive.abstract_eval(*avals, **params)
#    1318     out_avals = [out_avals] if not primitive.multiple_results else out_avals
#    1319     source_info = source_info_util.current()
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in standard_abstract_eval(prim, shape_rule, dtype_rule, weak_type_rule, named_shape_rule, *avals, **kwargs)
#    2272                          weak_type=weak_type)
#    2273   elif least_specialized is ShapedArray:
# -> 2274     return ShapedArray(shape_rule(*avals, **kwargs), dtype_rule(*avals, **kwargs),
#    2275                        weak_type=weak_type,
#    2276                        named_shape=named_shape_rule(*avals, **kwargs))
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in naryop_dtype_rule(result_dtype, accepted_dtypes, name, *avals, **kwargs)
#    2356         typenames = ', '.join(t.__name__ for t in types)
#    2357         raise TypeError(msg.format(name, typename, i, i, typenames))
# -> 2358   _check_same_dtypes(name, False, *aval_dtypes)
#    2359   return result_dtype(*avals)
#    2360
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in _check_same_dtypes(name, ignore_fp_precision, *ttypes)
#    7026     else:
#    7027       msg = "{} requires arguments to have the same dtypes, got {}."
# -> 7028     raise TypeError(msg.format(name, ", ".join(map(str, types))))
#    7029
#    7030
#
# TypeError: add requires arguments to have the same dtypes, got int32, float32.

# %%
# Example 2: lax is more powerful (but as a tradeoff less user-friendly)

x = jnp.array([1, 2, 1])
y = jnp.ones(10)

# NumPy API
result1 = jnp.convolve(x, y)

# lax API
result2 = lax.conv_general_dilated(
    x.reshape(1, 1, 3).astype(float),  # note: explicit promotion
    y.reshape(1, 1, 10),
    window_strides=(1,),
    padding=[(len(y) - 1, len(y) - 1)])  # equivalent of padding='full' in NumPy

print(result1)
print(result2[0][0])
assert np.allclose(result1, result2[0][0], atol=1E-6)

# XLA: https://www.tensorflow.org/xla/operation_semantics#convwithgeneralpadding_convolution
# Out:
# [1. 3. 4. 4. 4. 4. 4. 4. 4. 4. 3. 1.]
# [1. 3. 4. 4. 4. 4. 4. 4. 4. 4. 3. 1.]
