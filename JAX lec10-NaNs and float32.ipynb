# %%
import jax.numpy as jnp
import numpy as np
from jax import jit, grad, vmap
from jax import random
from jax import make_jaxpr
import matplotlib.pyplot as plt

# %% [markdown]
# # NaNs

# %%
jnp.divide(0., 0.)  # the default non-error behavior will simply return a NaN (as usually)

# If you want to debug where the NaNs are coming from, there are multiple ways
# to do that, here is one:
from jax.config import config
config.update("jax_debug_nans", True)
# Out:
# Invalid nan value encountered in the output of a C++-jit/pmap function. Calling the de-optimized version.
# Invalid value encountered in the output of a jit/pmap-ed function. Calling the de-optimized version.
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/jax/_src/api.py in _nan_check_posthook(fun, args, kwargs, output)
#     130   try:
# --> 131     xla.check_special(xla.xla_call_p, buffers)
#     132   except FloatingPointError:
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in check_special(name, bufs)
#     482     for buf in bufs:
# --> 483       _check_special(name, buf.xla_shape(), buf)
#     484
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in _check_special(name, xla_shape, buf)
#     488     if config.jax_debug_nans and np.any(np.isnan(buf.to_py())):
# --> 489       raise FloatingPointError(f"invalid value (nan) encountered in {name}")
#     490     if config.jax_debug_infs and np.any(np.isinf(buf.to_py())):
#
# FloatingPointError: invalid value (nan) encountered in xla_call
#
# During handling of the above exception, another exception occurred:
#
# FloatingPointError                        Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in _xla_call_impl(***failed resolving arguments***)
#     689   try:
# --> 690     out = compiled_fun(*args)
#     691   except FloatingPointError:
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in _execute_compiled(name, compiled, output_buffer_counts, handlers, kept_var_idx, *args)
#    1100   out_bufs = compiled.execute(input_bufs)
# -> 1101   check_special(name, out_bufs)
#    1102   if output_buffer_counts is None:
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in check_special(name, bufs)
#     482     for buf in bufs:
# --> 483       _check_special(name, buf.xla_shape(), buf)
#     484
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in _check_special(name, xla_shape, buf)
#     488     if config.jax_debug_nans and np.any(np.isnan(buf.to_py())):
# --> 489       raise FloatingPointError(f"invalid value (nan) encountered in {name}")
#     490     if config.jax_debug_infs and np.any(np.isinf(buf.to_py())):
#
# FloatingPointError: invalid value (nan) encountered in true_divide
#
# During handling of the above exception, another exception occurred:
#
# UnfilteredStackTrace                      Traceback (most recent call last)
# <ipython-input-4-bee0222788f8> in <module>()
# ----> 1 jnp.divide(0., 0.)  # the default non-error behavior will simply return a NaN (as usually)
#       2
#       3 # If you want to debug where the NaNs are coming from, there are multiple ways
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     161     try:
# --> 162       return fun(*args, **kwargs)
#     163     except Exception as e:
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/api.py in cache_miss(*args, **kwargs)
#     418         device=device, backend=backend, name=flat_fun.__name__,
# --> 419         donated_invars=donated_invars, inline=inline)
#     420     out_pytree_def = out_tree()
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in bind(self, fun, *args, **params)
#    1631   def bind(self, fun, *args, **params):
# -> 1632     return call_bind(self, fun, *args, **params)
#    1633
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1622   tracers = map(top_trace.full_raise, args)
# -> 1623   outs = primitive.process(top_trace, fun, tracers, params)
#    1624   return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1634   def process(self, trace, fun, tracers, params):
# -> 1635     return trace.process_call(self, fun, tracers, params)
#    1636
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     626   def process_call(self, primitive, f, tracers, params):
# --> 627     return primitive.impl(f, *tracers, **params)
#     628   process_map = process_call
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in _xla_call_impl(***failed resolving arguments***)
#     705     with core.new_sublevel():
# --> 706       _ = clone.call_wrapped(*args)  # probably won't return
#     707   return out
#
# /usr/local/lib/python3.7/dist-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py in true_divide(x1, x2)
#     842   x1, x2 = _promote_args_inexact("true_divide", x1, x2)
# --> 843   return lax.div(x1, x2)
#     844
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in div(x, y)
#     377   r"""Elementwise division: :math:`x \over y`."""
# --> 378   return div_p.bind(x, y)
#     379
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in bind(self, *args, **params)
#     271     tracers = map(top_trace.full_raise, args)
# --> 272     out = top_trace.process_primitive(self, tracers, params)
#     273     return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in process_primitive(self, primitive, tracers, params)
#     623   def process_primitive(self, primitive, tracers, params):
# --> 624     return primitive.impl(*tracers, **params)
#     625
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in apply_primitive(prim, *args, **params)
#     417                                         **params)
# --> 418   return compiled_fun(*args)
#     419
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in <lambda>(*args, **kw)
#     441   if not prim.multiple_results:
# --> 442     return lambda *args, **kw: compiled(*args, **kw)[0]
#     443   else:
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in _execute_compiled(name, compiled, output_buffer_counts, handlers, kept_var_idx, *args)
#    1100   out_bufs = compiled.execute(input_bufs)
# -> 1101   check_special(name, out_bufs)
#    1102   if output_buffer_counts is None:
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in check_special(name, bufs)
#     482     for buf in bufs:
# --> 483       _check_special(name, buf.xla_shape(), buf)
#     484
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/xla.py in _check_special(name, xla_shape, buf)
#     488     if config.jax_debug_nans and np.any(np.isnan(buf.to_py())):
# --> 489       raise FloatingPointError(f"invalid value (nan) encountered in {name}")
#     490     if config.jax_debug_infs and np.any(np.isinf(buf.to_py())):
#
# UnfilteredStackTrace: FloatingPointError: invalid value (nan) encountered in div
#
# The stack trace below excludes JAX-internal frames.
# The preceding is the original exception that occurred, unmodified.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# FloatingPointError                        Traceback (most recent call last)
# <ipython-input-4-bee0222788f8> in <module>()
# ----> 1 jnp.divide(0., 0.)  # the default non-error behavior will simply return a NaN (as usually)
#       2
#       3 # If you want to debug where the NaNs are coming from, there are multiple ways
#       4 # to do that, here is one:
#       5 from jax.config import config
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/api.py in _nan_check_posthook(fun, args, kwargs, output)
#     135     print("Invalid nan value encountered in the output of a C++-jit/pmap "
#     136           "function. Calling the de-optimized version.")
# --> 137     fun._cache_miss(*args, **kwargs)[0]  # probably won't return
#     138
#     139 def _update_debug_special_global(_):
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py in true_divide(x1, x2)
#     841 def true_divide(x1, x2):
#     842   x1, x2 = _promote_args_inexact("true_divide", x1, x2)
# --> 843   return lax.div(x1, x2)
#     844
#     845 divide = true_divide
#
# FloatingPointError: invalid value (nan) encountered in div

# %%
# JAX enforces single precision! There are simple ways around it though.
seed = 0
key = random.PRNGKey(seed)

x = random.uniform(key, (1000,), dtype=jnp.float64)
print(x.dtype)
# Out:
# float32

# %% [markdown]
# ##Final conclusions:
#
# - Excellent for researchers (very powerful, device agnostic code, etc.)
# - Definitely way too complicated for beginners (functional paradigm, optimization details, etc.) compared to PyTorch

# %% [markdown]
# Advanced referral:
# [link JAX](https://jax.readthedocs.io/en/latest/jax-101/01-jax-basics.html)
